# %% [markdown]
# In \[1\]:
#
#     # Import the required libraries
#     # pandas and numpy helps in the data analysis
#     # matplotlib . pyplot - it helps in the visualization . it creates the 2d plots
#     # seaborn - used for the advanced visualization  . helps in plotting the statistical plots
#     # like plotting 3d plots .
#     # seaborn is used when the plots is having the statiscal background then the seaborn is used .
#     # we are having the time amd datetime factor in the dataset so here we have imported the time
#     # and the datetime.
#     # %matplotlib inline - it is used so that the graph will be displayed within the plot .
#
#     import pandas as pd
#     import numpy as np
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     %matplotlib inline
#     import time
#     import datetime
#
# In \[2\]:
#
#     # here we  have created the variable called data
#     # then by using the pandas library we are reading the csv file
#
#     data = pd.read_csv('./seattleWeather_1948-2017.csv')
#
# In \[3\]:
#
#     # here we are checking the 1st 5 rows of the dataset
#
#     data.head()
#
# Out\[3\]:
#
# |     | DATE       | PRCP | TMAX | TMIN | RAIN |
# |-----|------------|------|------|------|------|
# | 0   | 1948-01-01 | 0.47 | 51   | 42   | True |
# | 1   | 1948-01-02 | 0.59 | 45   | 36   | True |
# | 2   | 1948-01-03 | 0.42 | 45   | 35   | True |
# | 3   | 1948-01-04 | 0.31 | 45   | 34   | True |
# | 4   | 1948-01-05 | 0.17 | 45   | 32   | True |
#
# In \[4\]:
#
#     # here we are checking the bottom 5 rows of the dataset
#
#     data.tail()
#
# Out\[4\]:
#
# |       | DATE       | PRCP | TMAX | TMIN | RAIN  |
# |-------|------------|------|------|------|-------|
# | 25546 | 2017-12-10 | 0.0  | 49   | 34   | False |
# | 25547 | 2017-12-11 | 0.0  | 49   | 29   | False |
# | 25548 | 2017-12-12 | 0.0  | 46   | 32   | False |
# | 25549 | 2017-12-13 | 0.0  | 48   | 34   | False |
# | 25550 | 2017-12-14 | 0.0  | 50   | 36   | False |
#
# In \[5\]:
#
#     # here we are checking the columns in data
#
#     data.columns
#
# Out\[5\]:
#
#     Index(['DATE', 'PRCP', 'TMAX', 'TMIN', 'RAIN'], dtype='object')
#
# In \[6\]:
#
#     # here we are checking the numerical elements present in the dataset
#     # it gives the summary statitics of the numeric variables
#     # firstly we will see the minimum value and the maximum value
#     # there should  not be so much of wide gap in the minimum and the maximum value
#
#     data.describe()
#
# Out\[6\]:
#
# |       | PRCP         | TMAX         | TMIN         |
# |-------|--------------|--------------|--------------|
# | count | 25548.000000 | 25551.000000 | 25551.000000 |
# | mean  | 0.106222     | 59.544206    | 44.514226    |
# | std   | 0.239031     | 12.772984    | 8.892836     |
# | min   | 0.000000     | 4.000000     | 0.000000     |
# | 25%   | 0.000000     | 50.000000    | 38.000000    |
# | 50%   | 0.000000     | 58.000000    | 45.000000    |
# | 75%   | 0.100000     | 69.000000    | 52.000000    |
# | max   | 5.020000     | 103.000000   | 71.000000    |
#
# In \[7\]:
#
#     # here we are checking the sum of the  null values present in the rows
#     #  axis=0 - it defines the rows
#
#     data.isna().sum(axis=0)
#
# Out\[7\]:
#
#     DATE    0
#     PRCP    3
#     TMAX    0
#     TMIN    0
#     RAIN    3
#     dtype: int64
#
# In \[8\]:
#
#     # here we are Finding  the rows having null values in the 'PRCP' columns in the dataset
#     # here we have used the pandas library
#
#     data[pd.isnull(data['PRCP'])]
#
# Out\[8\]:
#
# |       | DATE       | PRCP | TMAX | TMIN | RAIN |
# |-------|------------|------|------|------|------|
# | 18415 | 1998-06-02 | NaN  | 72   | 52   | NaN  |
# | 18416 | 1998-06-03 | NaN  | 66   | 51   | NaN  |
# | 21067 | 2005-09-05 | NaN  | 70   | 52   | NaN  |
#
# In \[9\]:
#
#     # Finding rows having null values in the 'RAIN' columns in the dataset
#     # here we have used the pandas library
#
#     data[pd.isnull(data['RAIN'])]
#
# Out\[9\]:
#
# |       | DATE       | PRCP | TMAX | TMIN | RAIN |
# |-------|------------|------|------|------|------|
# | 18415 | 1998-06-02 | NaN  | 72   | 52   | NaN  |
# | 18416 | 1998-06-03 | NaN  | 66   | 51   | NaN  |
# | 21067 | 2005-09-05 | NaN  | 70   | 52   | NaN  |
#
# In \[10\]:
#
#     # here we have used the seaborn libarray for the advanced visualization and for
#     # plotting the count plot
#     # then from the data we are plotting the data haveing the rain element on x axis
#     # so here  we are plotting the countplot from the data  having the rain element on the x axis
#
#     sns.countplot(data=data, x='RAIN')
#
# Out\[10\]:
#
#     <AxesSubplot:xlabel='RAIN', ylabel='count'>
#
# ![](data:image/png;base64,...%0A)
#
# In \[11\]:
#
#     # It is safer to insert a mean value in the PRCP column instead of dropping one row
#     # from  the above figure there is less chances  of rain
#     # so here we are inserting the mean in the precipitation column
#
#     data['PRCP'].mean()
#
# Out\[11\]:
#
#     0.10622162204477956
#
# In \[12\]:
#
#     # here we have created the customized function
#     # here the function name is RAIN_INSERTION
#     # then we craeted the variable called rain
#     # and we have used the def function
#     # we have applied this function on the column because rain insertion is in the column
#     # now come to the body of the function
#     # here we are creating the list where the rain is the 1st component of list
#     # o means the 1 element  that stores the result of rain into a list that the 1st element
#     # will be the value of rain
#     # in the 1st index we will have the rain value
#     # by using the if else condition to compute the rain value which will be in the 1st index of the
#     # list
#     # if there are null values in the rain column  then you will return the false or return rain
#     # def RAIN_INSERTION(cols) - this def function ill be applicable on the entire column of rain  .
#     # so it will checking all the column of rains if there is missing value it will put false over there
#
# In \[13\]:
#
#     # here we have given the  return 'False because rain the categorical variable
#     # here we cant find the mean of the rain
#
#     def RAIN_INSERTION(cols):
#         RAIN=cols[0]
#         if pd.isnull(RAIN):
#              return 'False'
#         else:
#              return RAIN
#
# In \[14\]:
#
#     #  here we have passes the parameter like col which means column
#     # store the precipatation valie in the 1st index that is column 0
#     #  then if there is a missing value in the precipatation column then you return the mean or else
#     # you will return the precipaptation element
#
#     def PRCP_INSERTION(col):
#         PRCP=col[0]
#         if pd.isnull(PRCP):
#              return data['PRCP'].mean()
#         else:
#             return PRCP
#
# In \[15\]:
#
#     # here we are Applying function to determine the chances of rain
#     # here we have selected the rain column from the data
#     # and applying the rain insertion function on the rain column  that is axis = 1
#     # axis 1 denotes the column
#     # and the column we have selected is rain
#     # the application of the rain insertion function on the rain column is done ,
#     # like once the operation is done the changes would be stored in the rain column of the data
#
#     data['RAIN']=data[['RAIN']].apply(RAIN_INSERTION,axis=1)
#
# In \[16\]:
#
#     # Applying function to determine the chances of having precipitation
#     # here we are Applying function to determine the chances of  precipitation
#     # here we have selected the precipitation  column from the data
#     # and applying thePRCP_INSERTION  function on the precipitation column  that is axis = 1
#     # axis 1 denotes the column
#     # and the column we have selected is precipitation
#     # the application of the PRCP_INSERTION function on the precipitation column is done ,
#     # like once the operation is done the changes would be stored in the precipitation column of the data
#
#     data['PRCP']=data[['PRCP']].apply(PRCP_INSERTION,axis=1)
#
# In \[17\]:
#
#     # here in the variable created data by using the pandas library we are checking for all the null
#     # values  in the data having the rain column
#
#     data[pd.isnull(data['RAIN'])]
#
# Out\[17\]:
#
# |     | DATE | PRCP | TMAX | TMIN | RAIN |
# |-----|------|------|------|------|------|
#
# In \[18\]:
#
#     # here in the variable created data by using the pandas library we are checking for all the
#     # null values  in the data having the precipitation column
#
#     data[pd.isnull(data['PRCP'])]
#
# Out\[18\]:
#
# |     | DATE | PRCP | TMAX | TMIN | RAIN |
# |-----|------|------|------|------|------|
#
# In \[19\]:
#
#     # First explore data for Temperature and Percipitation
#     # here we are plotting the graph  to see the relationship between the rain and the precipitation
#     # then we are giving the gridsize of the figure that is to be plotted with the height
#     # and weight of 7/7
#     # then we are plotting the scatter plot by giving the x and y elements that is the minimum
#     # tempreature and the precipitation by taking the elements from the data
#     # then we have given the name for x label and the y  label
#     # then we have given the  title of the scalletr plot
#     # bivariate analysis is important because it tells the relationship between the 2 independent
#     # variables
#     # bivariate analysis - it gives the most sophisticated results
#     # scatter plot will give the trend
#     # pair plot gives the  distribution between the two variables that how each variable is
#     # distributed plus  the density function of the scatter plot which shows the relationship
#     # between two variables
#
#     plt.scatter(x='TMIN',y='PRCP',data=data)
#     plt.xlabel('Minimum Temperature')
#     plt.ylabel('PRCP')
#     plt.title('Precipitation Vs Minimum Temperature')
#
# Out\[19\]:
#
#     Text(0.5, 1.0, 'Precipitation Vs Minimum Temperature')
#
# ![](data:image/png;base64,...%0A)
#
# In \[20\]:
#
#     # here we are giving the gridsize of the figure that is to be plotted with the height
#     # and weight of 7/7
#     # then we are plotting the scatter plot by giving the x and y elements that is the maximum
#     # tempreature and the precipitation by taking the elements from the data
#     # then we have given the name for x label and the y  label
#     # then we have given the  title of the scalletr plot
#
#     plt.figure(figsize=(7,7))
#     plt.scatter(x='TMAX',y='PRCP',data=data)
#     plt.xlabel('Maximum Temperature')
#     plt.ylabel('PRCP')
#     plt.title('Precipitation Vs Maximum Temperature')
#
# Out\[20\]:
#
#     Text(0.5, 1.0, 'Precipitation Vs Maximum Temperature')
#
# ![](data:image/png;base64,...%0A)
#
# In \[21\]:
#
#     # here we are Plotting the Distribution Plot
#     # here by using the seaborn libarary we are plotting the distribution plot by selecting the
#     # minimum temperture element from the data
#
#     sns.distplot(data['TMIN'])
#
#     C:\Users\Ankita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#       warnings.warn(msg, FutureWarning)
#
# Out\[21\]:
#
#     <AxesSubplot:xlabel='TMIN', ylabel='Density'>
#
# ![](data:image/png;base64,...%0A)
#
# In \[22\]:
#
#     # here we are Plotting the Distribution Plot
#     # here by using the seaborn libarary we are plotting the distribution plot by selecting the
#     # maximum temperture element from the data
#
#     sns.distplot(data['TMAX'])
#
#     C:\Users\Ankita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#       warnings.warn(msg, FutureWarning)
#
# Out\[22\]:
#
#     <AxesSubplot:xlabel='TMAX', ylabel='Density'>
#
# ![](data:image/png;base64,...%0A)
#
# In \[23\]:
#
#     # you have 3 plots in the pair plot - one is density plot and two histograms
#     # each histogram will show the distribution of the one variable
#     # pair plot means pair of 2 variables # density plot shows that
#     # how of the two variables are related to each other
#     # here  we are plotting he pair plot
#     # here by using the seaborn library we are plotting the pair plot  of the data from the data
#     #  here we can say that tmax and tmin are strongly correlated with each other
#     # we have created the plots in the same plot because we no need to create the
#     # same plot with the same code again and again.
#
#     sns.pairplot(data=data)
#
# Out\[23\]:
#
#     <seaborn.axisgrid.PairGrid at 0x1a7e420d3a0>
#
# ![](data:image/png;base64,...%0A)
#
# In \[24\]:
#
#     # here we are plotting the box plot
#     # here by using the seaborn library we are plotting the box plot of the data from the data
#
#     sns.boxplot(data=data)
#
# Out\[24\]:
#
#     <AxesSubplot:>
#
# ![](data:image/png;base64,...%0A)
#
# In \[25\]:
#
#     # OUTLIER TREATMENT
#
# In \[26\]:
#
#     # Dropping the outliers from TMIN column
#     # here we are dropping the TMIN column from the data  if the value is lower than 17
#
#     data=data.drop(data[data['TMIN']<17 ].index)
#
# In \[27\]:
#
#     # Dropping the outliers from TMAX columns i.e. the value more than 100
#     # here we are dropping the column TMAX  if the value is greater than 97.5
#     # and it will also drop the TMAX column having the value less than 21.5
#
#     data=data.drop(data[(data['TMAX']>97.5) | (data['TMAX']< 21.5)].index)
#
# In \[28\]:
#
#     # Dropping the outliers from PRCP columns i.e. the value more than 0.275
#     # here we are dropping the  precipitation column whose value should be greater than 0.25
#     # and we are also dropping  the precipitation column whose value should be less than 0.15
#
#     data=data.drop(data[(data['PRCP']>0.25) | (data['PRCP']< -0.15) ].index)
#
# In \[29\]:
#
#     # here by using the seaborn library  we are plotting the boxplot of the new data aboved from
#     # the entire/ previous data .
#
#     sns.boxplot(data=data)
#
#     # from the observations  as we can see that there is no outliers in the boxplot.
#
# Out\[29\]:
#
#     <AxesSubplot:>
#
# ![](data:image/png;base64,...%0A)
#
# In \[37\]:
#
#     # finally when we have clean data we will plot the logistic regression model
#
# In \[30\]:
#
#     # Importing Logistic Regression model
#     # here we are importing the  LogisticRegression module from the sklearn.linear_model pacakage.
#
#     from sklearn.linear_model import LogisticRegression
#
# In \[31\]:
#
#     # here we have created the variable called lr
#     # then we are passing the logistic regression to the new created variable called lr
#     #  whatever is there is on the left side is the object
#     # the lr object is created from the logistic regression class
#
#     lr= LogisticRegression()
#
# In \[32\]:
#
#     # Importing "train_test-split" function to test the model
#     # here we are importing train_test_split module from the sklearn.model_selection pacakge.
#
#     from sklearn.model_selection import train_test_split
#
# In \[33\]:
#
#     # here the date will not help to check that on which date there will be rain or not
#     # and rain element we need to drop because it is the independent variable .
#     # it cannot be the part of the feature set that is x
#     # here  x is the object or feature
#     # so here in the 1st line we are dropping the rain and date columns  from the data
#     # so we have used axis = 1 that denotes the columns
#     # mow in the y object  we are keep on retelling only the rain variable that is the
#     # independent variable
#     # y=y.astype('str') - here the rain will says yes/no , true/false . these are string
#     # values and we cannot keep the string values in analysis  but encoded this either
#     # so we will have to assert that the dependent variable can be a string value . store y as a string
#     # now we have created the 4 subsets of data
#     # here we have used the x train , y train  . this is the training set and from here the model learns
#     # from  x test , y test - this is used for testing the model
#     # while testing we will fit the x test set to the model and tell the model to predict
#     # and then we will apply the train test split function on the x and y
#     # here we have used the test size of 0.3 that means the dataset will be divided into 70/30 split .
#
#     X=data.drop(['RAIN','DATE'],axis=1)
#     y=data['RAIN']
#     y=y.astype('str')
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
#
# In \[38\]:
#
#     # here we have used  the random state so that we can get the similar assumptions or the results.
#
#     X=data.drop(['RAIN','DATE'],axis=1)
#     y=data['RAIN']
#     y=y.astype('str')
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)
#
# In \[34\]:
#
#     # Fit the model in train and test data
#     # here we are fitting the x train and the y train and alongside also we want the score of
#     # the train set that is the accuracy score
#     #  we want to find the accuracy score for the train set
#
#     lr.fit(X_train,y_train).score(X_train,y_train)
#
# Out\[34\]:
#
#     0.9138662316476346
#
# In \[35\]:
#
#     # Now fitting the model in test set
#     # here we have  created the variable called predictions
#     # here we are predicting the x test passing through lr in the prediction
#
#     prediction=lr.predict(X_test)
#
# In \[36\]:
#
#     # Printing first 5 rows after fitting the model in test set
#     # here we are printing the 1st 5 rows of the x test
#
#     print (X_test.head())
#
#            PRCP  TMAX  TMIN
#     11213  0.02    60    52
#     18062  0.00    74    51
#     19242  0.01    68    53
#     18925  0.14    54    45
#     2820   0.00    60    39
#
# In \[40\]:
#
#     # here we are importing metrics module from the sklearn package
#     # when you build the classification model as you want to judge the accuracy of the model
#     # then use the  confusion matrix
#     # we are using the confusion matrix because in the case of the regression modle we are using the
#     # r square that gives the goodness of fit means how fit the model is
#     # so whenever we will do the classification model we are having the confusion matrix to check the
#     # accuracy
#     # so the confusion matrix will give you the number of missclassification you make and the number
#     # of the correct classification you make
#     # then we have created the variable called cm
#     # then we are using the y test having the actual vaues and the prediction having the predictor values
#     # and passing it through the confusion matrix  by using the metrics module
#     # then we are printing the cm
#     # then we have created the another variable called accuracy
#     #  then we are checking the accuracy score of the y test actual values and the predictions that
#     # contains the predicted values  and passing it through the metrics module into the accuracy object
#     # then we are printing the accuracy score of the accuracy object / variable
#     # here cm stands for the confusion matrix
#
#     from sklearn import metrics
#     cm = metrics.confusion_matrix(y_test , prediction)
#     print (cm)
#     accuracy = metrics.accuracy_score(y_test , prediction)
#     print('Accuracy score;', accuracy)
#
#     [[3233 1180]
#      [1623  532]]
#     Accuracy score; 0.5732338611449452
#
# In \[41\]:
#
#     # what is missclassification
#     # if the real data set says that there will be rain but the model predicts that there is no
#     # rain then this is called as the missclassification
#
# In \[42\]:
#
#     # here we have created the variable called confusion matrix
#     # then we are using the y test actual values and the predictions that is the predictors in
#     # the confusion matrix and passing it through the metrics in the variable created called the
#     # confusion matrix.
#
#     confusion_matrix = metrics.confusion_matrix (y_test , prediction)
#
# In \[43\]:
#
#     # here we have created the variable called cm_display
#     # then we are using the confusion matrix to display the labels as true or false  in the confusion
#     # matrix and passing it through the Confusion Matrix Display through the metrics into the cm_display.
#
#     cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix
#                                                = confusion_matrix, display_labels = [False, True])
#
# In \[44\]:
#
#     # here we are plotting the confusion matrix display
#     # here we have used the plt.show() to get the graph in the systmatic manner.
#
#     cm_display.plot()
#     plt.show()
#
# ![](data:image/png;base64,...%0A)
#
# In \[ \]:
#
#
#
# In \[ \]:
